# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.pipeline import Pipeline

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.pipeline import Pipeline

df_train = pd.read_excel("/content/dataset_label_manual.xlsx")
df_test = pd.read_csv("/content/data_test (2).csv")

X_train = df_train["komentar"]
y_train = df_train["label_manual"]


model = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('svm', LinearSVC())
])

model.fit(X_train, y_train)

labeling = model.predict(df_test["komentar"])

df_test["label"] = labeling

df_test.to_csv("hasil_labeling_svm.csv", index=False)

print(df_test.head())
# Out:
#                                             komentar   label
# 0                             sidik kekayaan pejabat  netral
# 1  seperti terbalik tugas pokok sebagai perwakila...  netral
# 2  mereka adalah parasit di atas penderitaan raky...  netral
# 3         mntap pk ide2 ny,smga lbih sukses pk mntri  netral
# 4  terlalu lama dimanja sama mulyono dan mulyani ...  netral
